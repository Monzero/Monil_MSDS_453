# %% [markdown]
# ## FinRED Data Set
#
# The data set was obtained from https://github.com/soummyaah/FinRED/
#
# Here we are doing relationship extraction. This means when we are focusing on a document, it should contain the triplet : i.e entity1 , entity2 and relationship betweem them. For that the author has taken data from two sources: Webhouse financial News and second is ECT (earning call transcripts) from seekingalpha.com (June 2019 to September 2019). They used the presentation as well as the questionnaire portion of the transcript and remove monologues with less than 200 characters. In the ECT corpus, we have about 200K monologues, 1.8M sentences with an average of 7.19 sentences per monologue. In total, we have 152K tokens in the corpus.
#
# Wikidata KB is used for the relational triples.
#
# In total we obtain about 21,000 sentences using the distance supervision method, however a lot of these sentences are noisy. Eg: “Delhi-based National Housing Bank (NHB) is working
# to set up more than 80 new housing finance companies (HFCs), with a special emphasis on those that will focus on financing affordable houses." where the tuple is (More Than, industry, finance) since in Wikidata, “More Than“ is listed as an insurance company of the financial industry. We study a small representation of the data in detail and remove datapoints with incorrect entities such as “More Than“ and “industry“. After reduction, we get 7,775 sentences which we divide into the train, dev, and test dataset. We observe that this dataset only contains 920 sentences from the earnings call transcript and we attribute this to the earning call transcripts containing primarily conversational data which often does not contain a triplet in a sentence

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ##  Preamble

# %%
input_folder_path = '/Users/monilshah/Documents/02_NWU/10_MSDS_453_NLP/98_project_work/01_Input/01_FinRED_data/'
train_data_path   = input_folder_path + 'train.txt'
save_json_at    =  '/Users/monilshah/Documents/02_NWU/10_MSDS_453_NLP/98_project_work/02_wip_data/'

# %% [markdown]
# ## Load Data

# %%
f  = open(train_data_path,'r')
train_data = f.readlines()
len(train_data)
# Out:
# 5700

# %% [markdown]
# The structure of the data is such that we have a news line and there is tuple/triplet/trio of entities identified and relationship between them extracted. However, from the same document or news headline, it is possible to extract more than one triplets. Hence, one thought process is to not have the extraction strcutured in relational data table.
#
# I believe JSON would be a good way to store the information.

# %%
import json

# Sample line
line = 'NEW YORK (Reuters) - Apple Inc Chief Executive Steve Jobs sought to soothe investor concerns about his health on Monday, saying his weight loss was caused by a hormone imbalance that is relatively simple to treat. | Apple Inc ; Steve Jobs ; founded_by | Apple Inc ; Steve Jobs ; chief_executive_officer\n'

data_entries = []
count_skipped = 0

for line in train_data:
    # Step 1: Extract news line and entity relation.
    news_line, *entity_relations = line.strip().split(' | ')

    # Step 2: Parse each entity relationship into a dictionary format
    triples = []
    for entity_relation in entity_relations:
        try:
            # Attempt to unpack and strip
            subject, obj, relationship = map(str.strip, entity_relation.split(';'))
            triples.append({
                "subject": subject,
                "object": obj,
                "relation": relationship
            })
        except ValueError:
            # Skip if it doesn't unpack into exactly 3 values
            print(f'skiped following line : {line}')
            count_skipped += 1
            continue

    # Step 3: Create a dictionary with the news line and its corresponding triples
    if triples:  # Only add entries that have valid triples
        data_entry = {
            "news_line": news_line,
            "triples": triples
        }
        # Append to the list of entries
        data_entries.append(data_entry)


# Step 4: Save to JSON format
with open(save_json_at + 'relations_train_data.json', 'w') as file:
    json.dump([data_entries], file, indent=4)
    
print(f'Number of lines skipped : {count_skipped}')
# Out:
# skiped following line : Additionally, this quarter, the Federal Reserve Bank of Chicago is now a customer of Envestnet | Yodlee. | Envestnet ; Chicago ; headquarters_location
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Jul 29, 2015 00:37 IST Communications minister Ravi Shankar Prasad has said that the government is ready to help telecom operators in every way to fight the menace of call drops, but it won’t tolerate inaction. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Wed, Jul 22, 2015, 08:28 BST - UK Markets close in 8 hrs 2 mins FishBrain, 'Facebook for fishers', raises $8m in round led by Spotify backer By Lauren Davidson | Telegraph – 1 hour 28 minutes ago 33.125 +0.255 | Close ; Spotify ; distributed_by
#
# skiped following line : Sat, Jul 18, 2015, 15:48 BST - UK Markets closed Last chapter arrives for New York toy story FAO Schwarz By David Millward | Telegraph – 9 minutes ago 18.60 -0.13 | FAO Schwarz ; toy ; industry
#
# skiped following line : Moneylife » Tata Motors global sales remain flat in June 42798 Tata Motors global sales remain flat in June 0 Comments, Be the first to comment + COMMENT IANS | 17/07/2015 02:08 PM | Tata Motors global sales for the month of June 2015 including Jaguar Land Rover (JLR) remained flat at 76,602 units compared to the year ago period, Tata Motors announced on Thursday. | Tata Motors ; Jaguar Land Rover ; owner_of | Tata Motors ; Jaguar Land Rover ; subsidiary
#
# skiped following line : Moneylife » Tata Motors global sales remain flat in June 42798 Tata Motors global sales remain flat in June 0 Comments, Be the first to comment + COMMENT IANS | 17/07/2015 02:08 PM | Tata Motors global sales for the month of June 2015 including Jaguar Land Rover (JLR) remained flat at 76,602 units compared to the year ago period, Tata Motors announced on Thursday. | Tata Motors ; Jaguar Land Rover ; owner_of | Tata Motors ; Jaguar Land Rover ; subsidiary
#
# skiped following line : Mahua Venkatesh, Hindustan Times , New Delhi | Updated: Jul 08, 2015 00:22 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Photo Release -- Nasdaq Welcomes Natera Inc. to the Nasdaq Stock Market ET | Source: The NASDAQ OMX Group, Inc. photo-release Natera Inc., a leading genetic testing company that develops and commercializes non-invasive methods for analyzing DNA, opened for trading on The Nasdaq Stock Market on July 2, 2015. | Natera ; NASDAQ ; stock_exchange
#
# skiped following line : Mahua Venkatesh, Hindustan Times , New Delhi | Updated: Jul 19, 2015 23:32 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Picture: BLOOMBERG Related articles ArcelorMittal asks state for steel tariff protection Looming Evraz cash crunch cranks up steel industry crash ArcelorMittal takes a hit as sector bleeds In this article JSE-listed companies: ArcelorMittal SA | Evraz Highveld Steel and Vanadium People: Jacob Zuma WHEN the metals industry held its first summit recently, it was ignored by the executive. | Evraz ; steel ; product_or_material_produced
#
# skiped following line : Mon, Jul 20, 2015, 19:54 BST - UK Markets closed EU agrees to help Tunisia fight terror, boost economy European Union agrees to help Tunisia fight terror, boost its economy By John-Thor Dahlburg, Associated Press | Associated Press – 12 minutes ago View Photo | eu ; European Union ; operator
#
# skiped following line : Fri, Jul 17, 2015, 13:21 BST - UK Markets close in 3 hrs 9 mins Royal Mail shares drop as Ofcom launches ‘fundamental’ review of postal sector By Jon Yeomans | Telegraph – 46 minutes ago 512.50 -14.5000 | Ofcom ; postal sector ; industry
#
# skiped following line : Mon, Jul 20, 2015, 22:26 BST - UK Markets closed Gold falls to lowest level in five years on dollar strength Gold slumps to its lowest level in more than five years as demand for dollar stays strong By Marley Jay and Steve Rothwell, AP Business Writers | Associated Press – 23 minutes ago | Steve ; Associated Press ; employer
#
# skiped following line : Stratasys Ltd. 23/07/2015 | Press release Stratasys’ Solidscape and Kangshuo Group Launch Market Expansion in China With Largest 3D Printing Service Bureau Network | Stratasys ; 3D printing ; product_or_material_produced | Stratasys ; 3D printing ; industry | Stratasys ; Solidscape ; subsidiary
#
# skiped following line : Moneylife » Tata Motors to roll out new launches in mini-truck segment 42913 Tata Motors to roll out new launches in mini-truck segment 0 Comments, Be the first to comment + COMMENT IANS | 27/07/2015 05:03 PM | Tata Motors, a pioneer and market leader in the mini-truck segment in India, is working to develop innovative solutions on Tata Ace platform to cater to evolving needs of customers. | Tata Ace ; Tata Motors ; manufacturer | Tata Ace ; Tata Motors ; brand
#
# skiped following line : Moneylife » Tata Motors to roll out new launches in mini-truck segment 42913 Tata Motors to roll out new launches in mini-truck segment 0 Comments, Be the first to comment + COMMENT IANS | 27/07/2015 05:03 PM | Tata Motors, a pioneer and market leader in the mini-truck segment in India, is working to develop innovative solutions on Tata Ace platform to cater to evolving needs of customers. | Tata Ace ; Tata Motors ; manufacturer | Tata Ace ; Tata Motors ; brand
#
# skiped following line : Andrea Zanchi | E+ | Getty Images Both the CEO of Euronext Paris and the chief executive of Societe Generale said Tuesday that the French capital—better known for romance, Michelin-starred cuisine and the Eiffel Tower—could gain as a European financial hub in the event of a "Brexit." | Eiffel ; Paris ; location_of_formation
#
# skiped following line : Andrea Zanchi | E+ | Getty Images Both the CEO of Euronext Paris and the chief executive of Societe Generale said Tuesday that the French capital—better known for romance, Michelin-starred cuisine and the Eiffel Tower—could gain as a European financial hub in the event of a "Brexit." | Eiffel ; Paris ; location_of_formation
#
# skiped following line : Wed, Jul 8, 2015, 08:21 BST - UK Markets close in 8 hrs 9 mins Barclays Sacks Chief Executive Antony Jenkins By (c) Sky News 2015 | Sky News – 10 minutes ago View Photo | Antony Jenkins ; Barclays ; employer
#
# skiped following line : HDFC Bank steps up Haryana play, opens 300th branch By PTI | 8 Jul, 2015, 10.24PM IST   KARNAL, (HARYANA): HDFC Bank scaled up its Haryana presence today, by opening its new branch at Ramnagar here, its 300th one in the state. | hdfc ; HDFC Bank ; owned_by | hdfc ; HDFC Bank ; operator
#
# skiped following line : Warburg, General Atlantic eye buying private equities in Sharekhan worth Rs 2,300 crore By Reena Zachariah & Baiju Kalesh , ET Bureau | 8 Jul, 2015, 04.00AM IST ET SPECIAL: Love visual aspect of news? | Baiju ; general ; position_held
#
# skiped following line : Govt's next people plan: Take the BPOs to the hinterlands Suveen Sinha and M Rajendran, Hindustan Times , New Delhi | Updated: Jul 26, 2015 23:23 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Tushar Srivastava, Hindustan Times , New Delhi | Updated: Jul 29, 2015 11:42 IST Air India's Dreamliners are deployed on premium routes such as Rome, Milan, London, Sydney and Melbourne (File photo) | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Sun, Jul 12, 2015, 20:29 BST - UK Markets closed Eurozone sets Greece tough terms as euro exit looms By Danny Kemp | AFP – 24 minutes ago View Photo | Eurozone ; euro ; currency
#
# skiped following line : Himani Chandna, Hindustan Times , New Delhi | Updated: Jul 13, 2015 00:44 IST Rankings of cola giants have come down in the latest most preferred employers survey conducted by FirstNaukri.com. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Moneylife » General Motors to invest $1 bn in India 42929 General Motors to invest $1 bn in India 0 Comments, Be the first to comment IANS | 29/07/2015 04:31 PM | American automobile manufacturer General Motors (GM) on Wednesday said it will invest around $1 billion in India. | American ; automobile manufacturer ; industry
#
# skiped following line : Moneylife » General Motors to invest $1 bn in India 42929 General Motors to invest $1 bn in India 0 Comments, Be the first to comment IANS | 29/07/2015 04:31 PM | American automobile manufacturer General Motors (GM) on Wednesday said it will invest around $1 billion in India. | American ; automobile manufacturer ; industry
#
# skiped following line : Tue, Jul 28, 2015, 13:01 BST - UK Markets close in 3 hrs 29 mins Amazon Launches Own Music Streaming Service By (c) Sky News 2015 | Sky News – 8 minutes ago View Photo | Close ; music streaming ; distribution_format
#
# skiped following line : Business & Finance | 23 July 2015 16:26 CET Fortune Global 500 Leaders Look To Oxford Business Group For Data 2015 Index Provides New Boost For Publishing Firm By ModernGhana Business Desk | Global 500 ; Fortune ; creator
#
# skiped following line : Moneylife » Google Maps now available in 12 more Indian cities 42522 Google Maps now available in 12 more Indian cities 0 Comments, Be the first to comment + COMMENT IANS | 30/06/2015 04:42 PM | Starting Tuesday people can see traffic information for 12 new cities, including Kolkata, Thiruvananthapuram and Bhopal, on Google Maps, a company statement said here. | Google Maps ; Google ; developer
#
# skiped following line : Moneylife » Google Maps now available in 12 more Indian cities 42522 Google Maps now available in 12 more Indian cities 0 Comments, Be the first to comment + COMMENT IANS | 30/06/2015 04:42 PM | Starting Tuesday people can see traffic information for 12 new cities, including Kolkata, Thiruvananthapuram and Bhopal, on Google Maps, a company statement said here. | Google Maps ; Google ; developer
#
# skiped following line : Tushar Srivastava, Hindustan Times , New Delhi | Updated: Jul 05, 2015 23:31 IST A file photo of IndiGo Airlines A320 aircraft parked on the tarmac at Bengaluru International Airport in Bangalore. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Tushar Srivastava, Hindustan Times , New Delhi | Updated: Jul 03, 2015 02:56 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Moneylife » European Commission says Grexit cannot be ruled out 42701 European Commission says Grexit cannot be ruled out 0 Comments, Be the first to comment + COMMENT IANS | 08/07/2015 11:24 AM | At the end of a Eurogroup summit, European Commission President Jean-Claude Juncker said Grexit cannot be ruled out though he does not want Greece to leave the Eurozone. | Eurogroup ; Jean-Claude Juncker ; chairperson
#
# skiped following line : Moneylife » European Commission says Grexit cannot be ruled out 42701 European Commission says Grexit cannot be ruled out 0 Comments, Be the first to comment + COMMENT IANS | 08/07/2015 11:24 AM | At the end of a Eurogroup summit, European Commission President Jean-Claude Juncker said Grexit cannot be ruled out though he does not want Greece to leave the Eurozone. | Eurogroup ; Jean-Claude Juncker ; chairperson
#
# skiped following line : Leung | Getty Images Canary Wharf, London The banks named in the Cade probe are Bank of America Merrill Lynch , Bank of Tokyo-Mitsubishi UFJ , Barclays , Citigroup , Credit Suisse Group , Deutsche Bank , HSBC , JPMorgan Chase & Co , Morgan Stanley & Co , Nomura Holdings , Royal Bank of Canada , Royal Bank of Scotland Group , Standard Bank Group , Standard Chartered and UBS . | Standard Chartered ; London ; headquarters_location | Standard Bank ; London ; location_of_formation | Standard Chartered ; London ; location_of_formation
#
# skiped following line : Himani Chandna, Hindustan Times , New Delhi | Updated: Jul 18, 2015 00:24 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Sat, Jul 4, 2015, 00:54 BST - UK Markets closed Ferrari worth more than £7bn, says Fiat chief executive Sergio Marchionne By Reuters | Telegraph – 24 minutes ago Print | Sergio Marchionne ; Fiat ; employer
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Jul 30, 2015 17:34 IST According to Moody's report, India’s political infighting is denting business confidence and without a majority in the Upper House, the ruling BJP’s power has been “nullified” and the opposition has blocked proposed reforms. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : M Rajendran, Hindustan Times , New Delhi | Updated: Jul 04, 2015 00:27 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : BREAKING NEWS ICICI Bank may sell Home Finance arm for Rs 4,400 crore; Citibank roped in to find buyers By Sachin Dave , ET Bureau | 10 Jul, 2015, 12.58AM IST ET SPECIAL: Love visual aspect of news? | Citibank ; Finance ; industry
#
# skiped following line : Thu, Jul 30, 2015, 22:33 BST - UK Markets closed Amazon’s deal with Jeremy Clarkson shows the BBC licence fee is obsolete By Allister Heath | Telegraph – 1 hour 29 minutes ago 98.65 +1.50 | Jeremy Clarkson ; BBC ; employer
#
# skiped following line : State Bank of India chief Arundhati Bhattacharya spots modest recovery underway By PTI | 2 Jul, 2015, 08.05PM IST ET SPECIAL: Love visual aspect of news? | Arundhati Bhattacharya ; State Bank of India ; employer
#
# skiped following line : Fri, Jul 3, 2015, 11:59 BST - UK Markets close in 4 hrs 31 mins Reddit Boss Pleads With Users To End Blackout By (c) Sky News 2015 | Sky News – 4 minutes 53 seconds ago View Photo | Reddit ; news ; industry
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi |   23:49 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Nordstrom Earnings, Retail Sales on Tap for Thursday By U-Jin Lee | 08/12/15 - 08:15 PM EDT Reprint | Nordstrom ; retail ; industry
#
# skiped following line : Fri, Aug 7, 2015, 15:05 BST - UK Markets close in 1 hr 25 mins Yo Sushi enters Inflexion takeover talks as restaurant M&A conveyor rolls on By Oliver Haill | Sharecast – 22 minutes ago 35.995 +0.145 | Rolls ; restaurant ; industry
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Aug 04, 2015 12:58 IST Reserve Bank of India kept key interest rates unchanged. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Aug 15, 2015 00:54 IST Finance minister Arun Jaitley (L) with MoS finance Jayant Sinha. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Tushar Srivastava, Hindustan Times , New Delhi | Updated: Aug 14, 2015 11:57 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Tushar Srivastava, Hindustan Times , New Delhi | Updated: Aug 16, 2015 22:53 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Adam Jeffery | CNBC News Corporation building in New York News Corp. reported a better-than-expected quarterly profit on Wednesday, helped by cost cuts in its news and information services business that includes Dow Jones and The Wall Street Journal . | News Corporation ; The Wall Street Journal ; owner_of
#
# skiped following line : Bhadra Sinha, Hindustan Times , New Delhi | Updated: Aug 10, 2015 00:40 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Tue, Aug 11, 2015, 22:03 BST - UK Markets closed Drinkers toast brewing boom at British beer festival By Robin Millard | AFP – 42 minutes ago View Photo | brewing ; beer ; product_or_material_produced
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Aug 07, 2015 02:47 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : India receives $ 24 billion in FDI from EU in last 3 years By PTI | 9 Aug, 2015, 01.10PM IST   NEW DELHI: Despite the Free Trade Agreement talks with the European Union being in limbo, India has received an impressive $ 24 billion in Foreign Direct Investment from the 28-nation bloc over the last three years. | eu ; European Union ; operator
#
# skiped following line : Moneylife » Birla Corp in Rs.5,000 cr deal with Lafarge for cement units 43113 Birla Corp in Rs.5,000 cr deal with Lafarge for cement units 0 Comments, Be the first to comment + COMMENT IANS | 17/08/2015 04:16 PM | The M.P. | Lafarge ; cement ; product_or_material_produced
#
# skiped following line : Moneylife » Birla Corp in Rs.5,000 cr deal with Lafarge for cement units 43113 Birla Corp in Rs.5,000 cr deal with Lafarge for cement units 0 Comments, Be the first to comment + COMMENT IANS | 17/08/2015 04:16 PM | The M.P. | Lafarge ; cement ; product_or_material_produced
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Aug 06, 2015 01:19 IST Union finance minister Arun Jaitley. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : 0 Comments, Be the first to comment Yogesh Sapkale | 18/08/2015 11:42 AM | After much testing, Windows 10 is here and Microsoft is offering free upgrade Microsoft has started releasing volume licensing for its newest operating system (OS), Windows 10, from August 2015. | Windows 10 ; Microsoft ; developer
#
# skiped following line : 0 Comments, Be the first to comment Yogesh Sapkale | 18/08/2015 11:42 AM | After much testing, Windows 10 is here and Microsoft is offering free upgrade Microsoft has started releasing volume licensing for its newest operating system (OS), Windows 10, from August 2015. | Windows 10 ; Microsoft ; developer
#
# skiped following line : Kevin Lamarque | Reuters Janet Yellen "A weaker-than-expected rise in consumer prices at the start of Q3 further fuels the dovish argument for the Fed to remain on the sideline, delaying liftoff beyond the September FOMC meeting," Lindsey Piegza, chief economist at Stifel Fixed Income, said in a note. | Janet Yellen ; economist ; position_held
#
# skiped following line : Moneylife » Economy & Nation » Money & Banking » RBI to issue small finance bank licences next month 43161 RBI to issue small finance bank licences next month 0 Comments, Be the first to comment + COMMENT IANS | 20/08/2015 04:21 PM | The Reserve Bank of India (RBI) will issue licences to small finance banks to operate next month, RBI Governor Raghuram Rajan said on Thursday. | Raghuram Rajan ; Reserve Bank of India ; employer
#
# skiped following line : Moneylife » Economy & Nation » Money & Banking » RBI to issue small finance bank licences next month 43161 RBI to issue small finance bank licences next month 0 Comments, Be the first to comment + COMMENT IANS | 20/08/2015 04:21 PM | The Reserve Bank of India (RBI) will issue licences to small finance banks to operate next month, RBI Governor Raghuram Rajan said on Thursday. | Raghuram Rajan ; Reserve Bank of India ; employer
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Aug 13, 2015 00:57 IST | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : 0 BREAKING NEWS IDFC hires top executives from HDFC Bank for it's retail operations; plans to start business on October 1 By Atmadip Ray & Saikat Das , ET Bureau | 21 Aug, 2015, 04.00AM IST   KOLKATA | MUMBAI: IDFC Bank, which plans to begin business on October 1, has hired senior HDFC Bank executives to hammer out its retail strategy. | hdfc ; HDFC Bank ; owned_by | hdfc ; HDFC Bank ; operator
#
# skiped following line : 0 BREAKING NEWS IDFC hires top executives from HDFC Bank for it's retail operations; plans to start business on October 1 By Atmadip Ray & Saikat Das , ET Bureau | 21 Aug, 2015, 04.00AM IST   KOLKATA | MUMBAI: IDFC Bank, which plans to begin business on October 1, has hired senior HDFC Bank executives to hammer out its retail strategy. | hdfc ; HDFC Bank ; owned_by | hdfc ; HDFC Bank ; operator
#
# skiped following line : Wed, Aug 5, 2015, 01:26 BST - UK Markets open in 6 hrs 34 mins Iron Maiden star Bruce Dickinson restarts Djibouti's national airline By AFP | Telegraph – 1 minute 18 seconds ago 143.54 -0.15 | Bruce Dickinson ; Iron Maiden ; member_of
#
# skiped following line : Sruthin Lal, Hindustan Times , New Delhi | Updated: Aug 17, 2015 16:28 IST Ordinary traders are concerned over algorithmic trading and co location facility, calling them unfair (HT Photo) | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Mon, Aug 10, 2015, 17:11 BST - UK Markets closed US stocks climb as oil rebounds; Precision Castparts jumps US stocks climb as oil rebounds; Precision Castparts jumps on Buffett's $32 billion bid By Steve Rothwell, AP Business Writer | Associated Press – 15 minutes ago View Photo | Steve ; Associated Press ; employer
#
# skiped following line : Moneylife » Vodafone India to roll out 4G by 2015 end 43209 Vodafone India to roll out 4G by 2015 end 0 Comments, Be the first to comment + COMMENT IANS | 28/08/2015 03:44 PM | Vodafone India will launch its 4G services by end of 2015 in "important data markets" including Mumbai, Delhi, Kolkata, Bengaluru and Kochi, a company statement said here on Friday. | Vodafone India ; Vodafone ; parent_organization | Vodafone ; Vodafone India ; subsidiary
#
# skiped following line : Moneylife » Vodafone India to roll out 4G by 2015 end 43209 Vodafone India to roll out 4G by 2015 end 0 Comments, Be the first to comment + COMMENT IANS | 28/08/2015 03:44 PM | Vodafone India will launch its 4G services by end of 2015 in "important data markets" including Mumbai, Delhi, Kolkata, Bengaluru and Kochi, a company statement said here on Friday. | Vodafone India ; Vodafone ; parent_organization | Vodafone ; Vodafone India ; subsidiary
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Aug 22, 2015 07:24 IST File photo of Maruti Suzuki S-Cross. | Maruti Suzuki ; New Delhi ; headquarters_location | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : Sat, Aug 29, 2015, 22:16 BST - UK Markets closed Berkshire Hathaway builds stake in refiner Phillips 66 Berkshire Hathaway builds stake worth nearly $4.5 billion in refiner oil Phillips 66 By The Associated Press | Associated Press – 2 hours 8 minutes ago 77.23 +2.21 | Berkshire Hathaway ; Phillips 66 ; owner_of | Phillips 66 ; Berkshire Hathaway ; owned_by
#
# skiped following line : City News update: Tata Steel, Stagecoach, WPP, HSS City News update: Tata Steel, Stagecoach, WPP, HSS THE latest updates from City & Business… PUBLISHED: 12:42, Thu, Aug 27, 2015 | UPDATED: 12:47, Thu, Aug 27, 2015 GETTY TATA Steel to cut 250 jobs at South Wales plant Tata set to shed steel jobs | Tata Steel ; steel ; product_or_material_produced
#
# skiped following line : Wed, Aug 26, 2015, 20:06 BST - UK Markets closed Dividend Yields Are Soaring At Direct Line Insurance Group PLC, SSE PLC and Aberdeen Asset Management plc By Alan Oscroft | Fool.co.uk – 4 hours ago 1,420.00 -24.00 | Direct Line ; insurance ; product_or_material_produced
#
# skiped following line : Moneylife » Coal India earmarks Rs.60,000 crore capex for next five years 43455 Coal India earmarks Rs.60,000 crore capex for next five years 0 Comments, Be the first to comment + COMMENT IANS | 23/09/2015 07:11 PM | State-owned miner Coal India on Wednesday said it has earmarked Rs. | Coal India ; coal ; product_or_material_produced
#
# skiped following line : Moneylife » Coal India earmarks Rs.60,000 crore capex for next five years 43455 Coal India earmarks Rs.60,000 crore capex for next five years 0 Comments, Be the first to comment + COMMENT IANS | 23/09/2015 07:11 PM | State-owned miner Coal India on Wednesday said it has earmarked Rs. | Coal India ; coal ; product_or_material_produced
#
# skiped following line : Redmi 2 Prime 4G | Rs6,999 This device from Xiaomi is a successor to the Redmi 1S. | Redmi ; Xiaomi ; parent_organization | Redmi ; Xiaomi ; manufacturer
#
# skiped following line : Rate cut by HDFC Bank will not lead rate war By Sangita Mehta , ET Bureau | 16 Sep, 2015, 08.38PM IST   MUMBAI: A rate war that many expected after HDFC Bank slashed its lending rate is unlikely to happen, with most large commercial banks indicating that they will not follow suit at this point. | hdfc ; HDFC Bank ; owned_by | hdfc ; HDFC Bank ; operator
#
# skiped following line : Justin Solomon | CNBC Petrobras gas station in Brazil Petrobras has more than $100 billion in debt and a further downturn in the company could lead to widespread economic problems, given Brazil is one of the largest oil producers in the world, Cramer added. | Petrobras ; gas ; product_or_material_produced
#
# skiped following line : Mon, Sep 14, 2015, 16:46 BST - UK Markets closed Is Now The Perfect Time To Buy Gemfields PLC, Rare Earth Minerals PLC And Hochschild Mining Plc By Peter Stephens | Fool.co.uk – 35 minutes ago 1.041 -0.0240 | Gemfields ; mining ; industry
#
# skiped following line : Fri, Sep 11, 2015, 3:17 AM AEST - Australia Markets open in 6 hrs 43 mins 2 states' regulators oppose Patriot Coal reorganization plan Ohio, Pennsylvania regulators oppose Patriot Coal reorganization plan, cite pollution issues By Pam Ramsey, Associated Press | Associated Press – 44 minutes ago Recommend Print | Patriot Coal ; coal ; product_or_material_produced
#
# skiped following line : HT Correspondent, Hindustan Times , New Delhi | Updated: Sep 22, 2015 22:43 IST File photo of the Volkswagen Group logo. | Hindustan Times ; New Delhi ; headquarters_location
#
# skiped following line : 3 Clear Buying Signals For Tesco PLC, McColl’s Retail Group PLC And Debenhams Plc By Peter Stephens | Fool.co.uk – 25 minutes ago 165.15 -3.40 | Debenhams ; retail ; industry
#
# skiped following line : Tue, Sep 22, 2015, 10:56 BST - UK Markets close in 5 hrs 34 mins Snoop Dogg launches online 'marijuana hub' Merry Jane By Rebecca Burn-Callander | Telegraph – 4 minutes 40 seconds ago Print | Merry Jane ; Snoop Dogg ; founded_by
#
# skiped following line : Mike Segar | Reuters The Microsoft logo is seen at the Microsoft store in New York City. | Microsoft Store ; Microsoft ; parent_organization
#
# skiped following line : Sat, Sep 5, 2015, 6:11 AM AEST - Australia Markets closed US stocks drop as mixed jobs report keeps investors guessing US stocks sink as mixed jobs report keeps investors guessing about the rate outlook By Steve Rothwell, Business Writer | Associated Press – 57 minutes ago Recommend View Photo | Steve ; Associated Press ; employer
#
# skiped following line : Moneylife » 40 percent food retailers unaware of logistics costs: DHL 43607 40 percent food retailers unaware of logistics costs: DHL 0 Comments, Be the first to comment + COMMENT IANS | 08/10/2015 04:31 PM | Nearly 40 percent of Asian food retailers are unaware of logistics costs while six in 10 Indian food retailers are struggling to maintain adequate stocks, said a global logistics player DHL report released on Wednesday. | DHL ; logistics ; industry
#
# skiped following line : Moneylife » 40 percent food retailers unaware of logistics costs: DHL 43607 40 percent food retailers unaware of logistics costs: DHL 0 Comments, Be the first to comment + COMMENT IANS | 08/10/2015 04:31 PM | Nearly 40 percent of Asian food retailers are unaware of logistics costs while six in 10 Indian food retailers are struggling to maintain adequate stocks, said a global logistics player DHL report released on Wednesday. | DHL ; logistics ; industry
#
# Number of lines skipped : 90

# %% [markdown]
# Some 90 lines are getting skipped due to being in non-standard format out of 5700. We will not bother about that.

# %% [markdown]
# There are joint entity and relation extraction modules : SPN , TPLinker ,and CasRel
#
# Lets try to understand how SPN works
#
# Structured Prediction Network (SPN) is a neural network approach designed for tasks like relation extraction, where the goal is to identify relationships between entities in text. SPN works by learning to predict relationships in a structured way, often by modeling both entities and their relationships jointly within a single network. Here’s a high-level overview of how SPN-based relation extraction typically works:
#
# Key Steps in SPN-Based Relation Extraction
#
# Input Representation and Encoding:
#
# Entity and Sentence Encoding: The input text, typically a sentence, is tokenized and converted into embeddings (e.g., Word2Vec, GloVe, or contextual embeddings like BERT). Entity mentions within the text are marked, allowing the model to focus on specific entity pairs.
# Position Embeddings: The network also adds position embeddings, which encode the relative position of each word to the target entities, helping the model learn spatial relationships.
# Neural Network Architecture:
#
# SPNs often use bidirectional LSTMs (BiLSTMs), CNNs, or Transformers to encode the sentence context. By capturing contextual information, these networks provide a better understanding of the semantic relationships between entities.
# The encoded sentence and entity information is passed through several layers to produce a rich representation of the text and entities, highlighting relationships.
# Joint Entity and Relation Modeling:
#
# SPNs use structured prediction techniques to handle both entity recognition and relation classification simultaneously. Rather than treating entities and relations separately, SPNs predict relations between pairs of recognized entities within the context.
# This joint approach reduces error propagation between entity recognition and relation extraction, as both tasks benefit from shared context representations.
# Attention Mechanisms:
#
# Some SPNs incorporate attention mechanisms to weigh the importance of words around the entities, allowing the model to focus on parts of the sentence most relevant to the relationship.
# This is particularly useful in long or complex sentences where relevant relational information might not be located directly between the two entities.
# Structured Prediction Layer:
#
# The structured prediction layer generates a score or probability distribution over possible relationships between entities. This is usually done through a classification layer that considers the context vector from the previous steps.
# Some SPNs may also include constraints or dependencies to ensure that predicted relationships are consistent across the sentence.
# Training and Loss Function:
#
# SPNs use a loss function suited for multi-task learning, where both entities and relationships are predicted. This could be a cross-entropy loss for relation classification, combined with a loss function for entity recognition (e.g., span classification).
# SPNs are typically trained on annotated corpora with labeled entities and relationships, allowing the network to learn patterns in relation context and structure.
# Example of SPN in Action
# Consider a sentence like:
#
# "Apple Inc. CEO Steve Jobs introduced the iPhone."
#
# In this example:
#
# Entity Recognition identifies "Apple Inc." as an organization and "Steve Jobs" as a person.
# Relation Extraction then tries to identify the relationship between "Apple Inc." and "Steve Jobs," which might be labeled as "CEO_of" or "founder_of."
# The SPN jointly encodes both entities and the context in which they appear, focusing on the "introduced" action and the structure of the sentence to determine the specific relation.
#
# Advantages of SPNs for Relation Extraction
# Joint Entity and Relation Extraction: SPNs model entities and their relationships together, which improves accuracy over models that treat these tasks separately.
# Reduced Error Propagation: Since both tasks are handled together, SPNs reduce the issue where errors in entity recognition lead to incorrect relation extraction.
# Flexibility with Context and Structure: The SPN’s use of structured context encoding helps capture complex relational information, making it suitable for various types of entity relationships.
# Practical Considerations
# SPNs and similar architectures often rely on large labeled datasets for training, especially if using deep contextual models like BERT. Fine-tuning on domain-specific data can improve performance for specialized relation extraction tasks, such as extracting medical relations or financial connections.
#
# In summary, SPNs are an effective, context-aware architecture for relation extraction that leverages joint entity and relationship prediction within a structured framework, often using LSTMs, CNNs, or Transformers combined with attention mechanisms to capture complex dependencies and improve accuracy.
